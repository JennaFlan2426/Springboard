# %% [markdown]
# # Exploring Price and SEC data for a single company

# %% [markdown]
# ## Objectives:

# %% [markdown]
# - Explore data and feature relationships within a single company, over time
# - Develop a process that can be repeated for each company in a dataset
#     - Decide if I want to work with a specific time frame or "whatever is available for this company". Is it better to do analysis on all the observations or to make the dataset for each company as much like the others as I can?
# - Add calculated fields as necessary for analysis ratios, as in price/earnings or price/book, etc

# %% [markdown]
# ## Recap of project questions:

# %% [markdown]
# - My core question so far is, are market prices correlated with valuation information in some fashion?
#     - If so, which valuation information is most strongly correlated?
#     - What, if any, is the relationship between stock price/market capitalization and the business's balance sheet?
#     - Do any of these data include attempts to put a value on intangibles such as goodwill/reputation?
#     - The fundamental analysis tradition focuses on ratios of price to earnings, book value, earnings growth; do the ratios that investors find acceptable change over time? Do they tend to change back (or ahead) when SEC filings are released?
#     - (Do I have time for this?) What happens in the periods between filings? Do prices maintain a range, like the moving average support/resistance bands favored by technical analysis?

# %% [markdown]
# ## Last time on data wrangling...

# %% [markdown]
# - I produced a CSV file containing a combination of SEC filing data with stock price data for each of the date of filing, the date before, and the date after the filing.
# - Some filings will be missing the "before" or "after" prices, most likely due to the filing date falling on a Friday or Monday; for the sake of the project I have accepted this as not problematic enough (yet) to be worth the work to figure out how to query for data in a way that says "give me the date immediately before this, and if you don't find that date, then go back 3 days instead".
# - Price data may be "interesting" to work with in this format, as I have essentially created a tiny time series within each point of a much larger and less granular time series.

# %% [markdown]
# ## New questions:

# %% [markdown]
# - Can I compare my sets of 3-day prices to each other?
#     - Are there patterns that seem consistent? As a guess, do prices often go up or down the day of an SEC release? Do they tend to sustain any changes through the day after? What about the magnitude of the differences?
# - How do I best account for the "over time" qualities of this data?
#     - https://machinelearningmastery.com/basic-feature-engineering-time-series-data-python/
#     - https://machinelearningmastery.com/moving-average-smoothing-for-time-series-forecasting-python/
# - I am also interested in the scale of changes from one time point to another, such as, if the company's asset value has changed by x% between the previous filing and the current one, does the stock price change by a similar percentage?

# %% [markdown]
# ### 1. Import modules and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from cycler import cycler

# %%
df = pd.read_csv('hf-3-day-prices.csv', parse_dates=['date', 'date_minus1', 'date_plus1'])
# df.head()

# %%
df_ticker = df[df['ticker'] == 'AAPL']
# df_ticker.head()

# %%
df_ticker.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 36 to 74
# Data columns (total 63 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ticker                            39 non-null     object
#  1   date                              39 non-null     datetime64[ns]
#  2   commonstocksharesissued           39 non-null     float64
#  3   assetscurrent                     39 non-null     float64
#  4   accountspayablecurrent            39 non-null     float64
#  5   commonstockvalue                  24 non-null     float64
#  6   liabilities                       39 non-null     float64
#  7   liabilitiesandstockholdersequity  39 non-null     float64
#  8   stockholdersequity                39 non-null     float64
#  9   earningspersharebasic             39 non-null     float64
#  10  netincomeloss                     39 non-null     float64
#  11  profitloss                        0 non-null      float64
#  12  costofgoodssold                   0 non-null      float64
#  13  costsandexpenses                  0 non-null      float64
#  14  cash                              11 non-null     float64
#  15  notespayable                      0 non-null      float64
#  16  preferredstockvalue               0 non-null      float64
#  17  depreciation                      0 non-null      float64
#  18  operatingexpenses                 39 non-null     float64
#  19  revenues                          5 non-null      float64
#  20  land                              0 non-null      float64
#  21  accountsreceivablenet             0 non-null      float64
#  22  deferredrevenue                   0 non-null      float64
#  23  grossprofit                       39 non-null     float64
#  24  sharesissued                      7 non-null      float64
#  25  accruedincometaxes                0 non-null      float64
#  26  sharesoutstanding                 0 non-null      float64
#  27  borrowedfunds                     0 non-null      float64
#  28  inventorygross                    0 non-null      float64
#  29  commercialpaper                   39 non-null     float64
#  30  dividends                         39 non-null     float64
#  31  commonstocknoparvalue             0 non-null      float64
#  32  costofservices                    0 non-null      float64
#  33  debtcurrent                       0 non-null      float64
#  34  accruedinsurancecurrent           0 non-null      float64
#  35  officerscompensation              0 non-null      float64
#  36  salariesandwages                  0 non-null      float64
#  37  interestanddebtexpense            0 non-null      float64
#  38  convertibledebt                   0 non-null      float64
#  39  operatingcycle                    0 non-null      object
#  40  open                              39 non-null     float64
#  41  high                              39 non-null     float64
#  42  low                               39 non-null     float64
#  43  close                             39 non-null     float64
#  44  close_adjusted                    39 non-null     float64
#  45  volume                            39 non-null     float64
#  46  split_coefficient                 39 non-null     float64
#  47  date_minus1                       35 non-null     datetime64[ns]
#  48  open_minus1                       35 non-null     float64
#  49  high_minus1                       35 non-null     float64
#  50  low_minus1                        35 non-null     float64
#  51  close_minus1                      35 non-null     float64
#  52  close_adj_minus1                  35 non-null     float64
#  53  volume_minus1                     35 non-null     float64
#  54  split_coef_minus1                 35 non-null     float64
#  55  date_plus1                        36 non-null     datetime64[ns]
#  56  open_plus1                        36 non-null     float64
#  57  high_plus1                        36 non-null     float64
#  58  low_plus1                         36 non-null     float64
#  59  close_plus1                       36 non-null     float64
#  60  close_adj_plus1                   36 non-null     float64
#  61  volume_plus1                      36 non-null     float64
#  62  split_coef_plus1                  36 non-null     float64
# dtypes: datetime64[ns](3), float64(58), object(2)
# memory usage: 19.5+ KB

# %%
# To reduce complexity, drop null columns:
df_ticker = df_ticker.dropna(axis='columns', how='all')
df_ticker.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 36 to 74
# Data columns (total 41 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ticker                            39 non-null     object
#  1   date                              39 non-null     datetime64[ns]
#  2   commonstocksharesissued           39 non-null     float64
#  3   assetscurrent                     39 non-null     float64
#  4   accountspayablecurrent            39 non-null     float64
#  5   commonstockvalue                  24 non-null     float64
#  6   liabilities                       39 non-null     float64
#  7   liabilitiesandstockholdersequity  39 non-null     float64
#  8   stockholdersequity                39 non-null     float64
#  9   earningspersharebasic             39 non-null     float64
#  10  netincomeloss                     39 non-null     float64
#  11  cash                              11 non-null     float64
#  12  operatingexpenses                 39 non-null     float64
#  13  revenues                          5 non-null      float64
#  14  grossprofit                       39 non-null     float64
#  15  sharesissued                      7 non-null      float64
#  16  commercialpaper                   39 non-null     float64
#  17  dividends                         39 non-null     float64
#  18  open                              39 non-null     float64
#  19  high                              39 non-null     float64
#  20  low                               39 non-null     float64
#  21  close                             39 non-null     float64
#  22  close_adjusted                    39 non-null     float64
#  23  volume                            39 non-null     float64
#  24  split_coefficient                 39 non-null     float64
#  25  date_minus1                       35 non-null     datetime64[ns]
#  26  open_minus1                       35 non-null     float64
#  27  high_minus1                       35 non-null     float64
#  28  low_minus1                        35 non-null     float64
#  29  close_minus1                      35 non-null     float64
#  30  close_adj_minus1                  35 non-null     float64
#  31  volume_minus1                     35 non-null     float64
#  32  split_coef_minus1                 35 non-null     float64
#  33  date_plus1                        36 non-null     datetime64[ns]
#  34  open_plus1                        36 non-null     float64
#  35  high_plus1                        36 non-null     float64
#  36  low_plus1                         36 non-null     float64
#  37  close_plus1                       36 non-null     float64
#  38  close_adj_plus1                   36 non-null     float64
#  39  volume_plus1                      36 non-null     float64
#  40  split_coef_plus1                  36 non-null     float64
# dtypes: datetime64[ns](3), float64(37), object(1)
# memory usage: 12.8+ KB

# %% [markdown]
# ### 2. Start visualizing!

# %%
# still too many columns for pairplot. Let's try heatmap.
corrmap = df_ticker.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(round(corrmap,2), ax=ax, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Well, this is an interesting quilt pattern. I didn't expect these patterns of... correlation flips, I guess I would call it.
# - I didn't expect the various price columns to be so universally 100% positive with their alternate days.
# - I didn't expect prices to be so often negatively correlated to filing data, and especially not for the correlations to all reverse for close_adj and volume columns
# - It might be naive, on reflection, that I was surprised by the strong positive associations between business assets and liabilities. I have a sense, although I can't cite sources off the top of my head, that businesses are generally encouraged to keep debts as nearly in sync with their assets as lenders will allow, as a way to turn the value of illiquid assets into money the business can use more immediately.
# - I would say the correlations between 'commonstocksharesissued' and 'commonstockvalue', especially vis-a-vis prices, are basically a given. However, I wonder if even this relationship might change in scale when viewed over time?
# - I'm also surprised at how nearly uncorrelated dividends are to just about everything else on the board.
#
# Is there a good way to explore some of these relationships over time, preferably in subsets so I don't bury myself in plots?

# %% [markdown]
# #### Plot close price vs 'close_adjusted' over time. Does that help tell me why they are oppositely correlated to most filing data?

# %%
x = df_ticker[['date']]
y = df_ticker[['close', 'close_adjusted']]
y_minus = df_ticker[['close_minus1', 'close_adj_minus1']]
y_plus = df_ticker[['close_plus1', 'close_adj_plus1']]

cc = (cycler(color=list('rgb')) * cycler(linestyle=['-', '--']))
plt.subplots(figsize=(12, 9))
plt.plot(x, y)
plt.plot(x, y_minus)
plt.plot(x, y_plus)
plt.rc('axes', prop_cycle=cc)
ax.legend(loc='upper right')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Again, not what I expected. Some kind of big stock split in 2014? That would explain a bunch of the correlation weirdness.

# %%
df_2014 = df_ticker[df_ticker['date'].dt.year == 2014]
df_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 54 to 57
# Data columns (total 41 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ticker                            4 non-null      object
#  1   date                              4 non-null      datetime64[ns]
#  2   commonstocksharesissued           4 non-null      float64
#  3   assetscurrent                     4 non-null      float64
#  4   accountspayablecurrent            4 non-null      float64
#  5   commonstockvalue                  1 non-null      float64
#  6   liabilities                       4 non-null      float64
#  7   liabilitiesandstockholdersequity  4 non-null      float64
#  8   stockholdersequity                4 non-null      float64
#  9   earningspersharebasic             4 non-null      float64
#  10  netincomeloss                     4 non-null      float64
#  11  cash                              0 non-null      float64
#  12  operatingexpenses                 4 non-null      float64
#  13  revenues                          0 non-null      float64
#  14  grossprofit                       4 non-null      float64
#  15  sharesissued                      0 non-null      float64
#  16  commercialpaper                   4 non-null      float64
#  17  dividends                         4 non-null      float64
#  18  open                              4 non-null      float64
#  19  high                              4 non-null      float64
#  20  low                               4 non-null      float64
#  21  close                             4 non-null      float64
#  22  close_adjusted                    4 non-null      float64
#  23  volume                            4 non-null      float64
#  24  split_coefficient                 4 non-null      float64
#  25  date_minus1                       3 non-null      datetime64[ns]
#  26  open_minus1                       3 non-null      float64
#  27  high_minus1                       3 non-null      float64
#  28  low_minus1                        3 non-null      float64
#  29  close_minus1                      3 non-null      float64
#  30  close_adj_minus1                  3 non-null      float64
#  31  volume_minus1                     3 non-null      float64
#  32  split_coef_minus1                 3 non-null      float64
#  33  date_plus1                        4 non-null      datetime64[ns]
#  34  open_plus1                        4 non-null      float64
#  35  high_plus1                        4 non-null      float64
#  36  low_plus1                         4 non-null      float64
#  37  close_plus1                       4 non-null      float64
#  38  close_adj_plus1                   4 non-null      float64
#  39  volume_plus1                      4 non-null      float64
#  40  split_coef_plus1                  4 non-null      float64
# dtypes: datetime64[ns](3), float64(37), object(1)
# memory usage: 1.3+ KB

# %%
df_2014['commonstocksharesissued']
# Out:
# 54    8.924470e+08
# 55    8.992130e+05
# 56    6.294494e+09
# 57    5.866161e+09
# Name: commonstocksharesissued, dtype: float64

# %%
df_2014['split_coefficient']
df_2014['split_coef_plus1']
# Out:
# 54    1.0
# 55    1.0
# 56    1.0
# 57    1.0
# Name: split_coef_plus1, dtype: float64

# %%
df_2014['close']
# Out:
# 54    506.50
# 55    567.77
# 56     97.19
# 57    105.11
# Name: close, dtype: float64

# %% [markdown]
# Price data doesn't seem to be recognizing it as a split and the shares issued numbers are pretty wierd. 8.92e+08, down to e+05, up to 6.29e+09... the jump up matches the price change, is the second figure an error?

# %%
df_2013 = df_ticker[df_ticker['date'].dt.year == 2013]
df_2013['commonstocksharesissued']
# Out:
# 50    939208000.0
# 51    939208000.0
# 52    939208000.0
# 53    939208000.0
# Name: commonstocksharesissued, dtype: float64

# %%
df_ticker[df_ticker['date'].dt.year.isin([2013, 2014])]
# Out:
#    ticker       date  commonstocksharesissued  assetscurrent  \
# 50   AAPL 2013-01-24             9.392080e+08   5.765300e+10
# 51   AAPL 2013-04-24             9.392080e+08   5.765300e+10
# 52   AAPL 2013-07-24             9.392080e+08   5.765300e+10
# 53   AAPL 2013-10-30             9.392080e+08   5.765300e+10
# 54   AAPL 2014-01-28             8.924470e+08   8.034700e+10
# 55   AAPL 2014-04-24             8.992130e+05   7.328600e+10
# 56   AAPL 2014-07-23             6.294494e+09   7.328600e+10
# 57   AAPL 2014-10-27             5.866161e+09   6.853100e+10
#
#     accountspayablecurrent  commonstockvalue   liabilities  \
# 50            2.117500e+10      1.642200e+10  5.785400e+10
# 51            2.117500e+10      1.642200e+10  5.785400e+10
# 52            2.117500e+10      1.642200e+10  5.785400e+10
# 53            2.117500e+10      1.642200e+10  5.785400e+10
# 54            2.958800e+10      2.055900e+10  9.550000e+10
# 55            2.236700e+10               NaN  8.345100e+10
# 56            2.236700e+10               NaN  8.345100e+10
# 57            3.019600e+10               NaN  1.202920e+11
#
#     liabilitiesandstockholdersequity  stockholdersequity  \
# 50                      1.760640e+11        1.182100e+11
# 51                      1.760640e+11        1.182100e+11
# 52                      1.760640e+11        1.182100e+11
# 53                      1.760640e+11        4.990000e+08
# 54                      2.251840e+11        1.296840e+11
# 55                      2.070000e+11        1.235490e+11
# 56                      2.070000e+11        1.235490e+11
# 57                      2.318390e+11        2.331300e+10
#
#     earningspersharebasic  ...  volume_minus1  split_coef_minus1  date_plus1  \
# 50                  14.03  ...     30768200.0                1.0  2013-01-25
# 51                  10.16  ...     23722800.0                1.0  2013-04-25
# 52                   7.51  ...     13192700.0                1.0  2013-07-25
# 53                  14.03  ...     22707400.0                1.0  2013-10-31
# 54                  14.59  ...     19817100.0                1.0  2014-01-29
# 55                  11.69  ...     14105000.0                1.0  2014-04-25
# 56                   1.29  ...     55197000.0                1.0  2014-07-24
# 57                   1.43  ...            NaN                NaN  2014-10-28
#
#     open_plus1  high_plus1  low_plus1  close_plus1  close_adj_plus1  \
# 50     451.690      456.23     435.00      439.880          56.8367
# 51     411.225      413.94     407.00      408.380          53.0652
# 52     440.700      441.40     435.81      438.500          57.3595
# 53     525.000      527.49     521.27      522.702          68.8262
# 54     503.950      507.37     498.62      500.750          66.3218
# 55     564.530      571.99     563.96      571.940          76.2013
# 56      97.035       97.32      96.42       97.030          90.9996
# 57     105.400      106.74     105.35      106.740         100.6042
#
#     volume_plus1  split_coef_plus1
# 50    43143800.0               1.0
# 51    13744200.0               1.0
# 52     8196200.0               1.0
# 53     9846300.0               1.0
# 54    17957500.0               1.0
# 55    13938400.0               1.0
# 56    45729000.0               1.0
# 57    48060949.0               1.0
#
# [8 rows x 41 columns]

# %% [markdown]
# https://investor.apple.com/faq/default.aspx#:~:text=Apple's%20stock%20has%20split%20five,%2C%20and%20June%2016%2C%201987.
# Says yes, there was a 7-for-1 split in June 2014.
#
# Looking at the CSV, I think the April 2014 share number is a typo; numbers both before and after end in a round thousand, but this one is missing the 3 trailing 0's.
#
# If I understand split adjusting correctly, I should only use the "adjusted" price numbers, which means tossing out all the open/high/low/close columns. (Simpler data might not be such a bad thing...)
#
# If I understand the "split coefficient" correctly it should not be 1.0 all this time. If it is, it's kind of useless.

# %%
df_ticker.split_coefficient.unique()
# Out:
# array([1.])

# %%
df_ticker.split_coef_minus1.unique()
# Out:
# array([ 1., nan])

# %%
df_ticker.split_coef_plus1.unique()
# Out:
# array([ 1., nan])

# %%
dropcols = ['open', 'high', 'low', 'close', 'split_coefficient', 'open_minus1', 'high_minus1', 'low_minus1', 'close_minus1', 
            'split_coef_minus1', 'open_plus1', 'high_plus1', 'low_plus1', 'close_plus1', 'split_coef_plus1']
df_ticker = df_ticker.drop(dropcols, axis=1)
df_ticker.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 36 to 74
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ticker                            39 non-null     object
#  1   date                              39 non-null     datetime64[ns]
#  2   commonstocksharesissued           39 non-null     float64
#  3   assetscurrent                     39 non-null     float64
#  4   accountspayablecurrent            39 non-null     float64
#  5   commonstockvalue                  24 non-null     float64
#  6   liabilities                       39 non-null     float64
#  7   liabilitiesandstockholdersequity  39 non-null     float64
#  8   stockholdersequity                39 non-null     float64
#  9   earningspersharebasic             39 non-null     float64
#  10  netincomeloss                     39 non-null     float64
#  11  cash                              11 non-null     float64
#  12  operatingexpenses                 39 non-null     float64
#  13  revenues                          5 non-null      float64
#  14  grossprofit                       39 non-null     float64
#  15  sharesissued                      7 non-null      float64
#  16  commercialpaper                   39 non-null     float64
#  17  dividends                         39 non-null     float64
#  18  close_adjusted                    39 non-null     float64
#  19  volume                            39 non-null     float64
#  20  date_minus1                       35 non-null     datetime64[ns]
#  21  close_adj_minus1                  35 non-null     float64
#  22  volume_minus1                     35 non-null     float64
#  23  date_plus1                        36 non-null     datetime64[ns]
#  24  close_adj_plus1                   36 non-null     float64
#  25  volume_plus1                      36 non-null     float64
# dtypes: datetime64[ns](3), float64(22), object(1)
# memory usage: 8.2+ KB

# %%
plt.rcdefaults()
corrmap = df_ticker.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(round(corrmap,2), ax=ax, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# I wonder why, of the columns with few values, 'cash' and 'sharesissued' are coming out blank but 'revenues' gets a correlation on only 5 non-null rows?

# %%
# let's try plotting subsets of columns over time. 
# picking a group with somewhat similar scales, although maybe I should show these in log scale?
columns = list(df_ticker.columns.values)
ss1 = columns[3:9]
y = df_ticker[ss1]
plt.plot(x, y)
plt.legend(labels = ss1)
plt.show()

# %%
ss2 = columns[10:16]
y = df_ticker[ss2]
plt.plot(x, y)
plt.legend(labels = ss2)
plt.show()

# %%
ss3 = ['commonstocksharesissued'] + columns[16:18]
y = df_ticker[ss3]
plt.plot(x, y)
plt.legend(labels = ss3)
plt.show()

# %%
ss4 = ['earningspersharebasic', 'close_adjusted', 'close_adj_minus1', 'close_adj_plus1']
y = df_ticker[ss4]
plt.plot(x, y)
plt.legend(labels = ss4)
plt.show()

# %% [markdown]
# I see some interesting trends, and I think I'm getting a bit off track.
# - Is the "over time" part more or less important than the "correlation" part?
# - Stockholders' equity looks like it's trending downward since 2014
# - By eyeball, the price/earnings ratio has skyrocketed... on earnings that are flat-to-falling over time
# - Liabilities seem to be going up faster than assets
# - Gross profit has leaped in the last 3 years but very volatile. Net income and operating expenses showing similar increases.
# - As I get further into details, it's getting hard to think how I would repeat this process for multiple companies.

# %% [markdown]
# ## Mentor review:
# - Look for some tickers that have more reporting (especially revenue)
# - Try the linear regressions
# - Try statistical tests (normality; histograms)
# - See if multiple companies in a sector are workable (top 5 and/or most complete data)

# %% [markdown]
# #### Look for some tickers that have more reporting (especially revenue), and
# #### See if multiple companies in a sector are workable (top 5 and/or most complete data)
# Limiting to "tech stocks" since multi-company comparisons ought to account for industry

# %%
print(df.ticker.unique())
# Out:
# ['AAL' 'AAPL' 'ABBV' 'ABC' 'ACI' 'ADM' 'AIG' 'ALL' 'AMZN' 'ANTM' 'AXP'
#  'BA' 'BAC' 'BBY' 'CAH' 'CAT' 'CHTR' 'CI' 'CNC' 'COF' 'COP' 'COST' 'CSCO'
#  'CVS' 'CVX' 'DAL' 'DE' 'DOW' 'EXC' 'F' 'FB' 'FDX' 'GD' 'GE' 'GM' 'GOOGL'
#  'HCA' 'HD' 'HON' 'HPQ' 'HUM' 'IBM' 'INT' 'INTC' 'JNJ' 'KO' 'KR' 'LMT'
#  'LOW' 'MCK' 'MET' 'MPC' 'MRK' 'MS' 'MSFT' 'NKE' 'NOC' 'ORCL' 'PAGP' 'PEP'
#  'PFE' 'PG' 'PGR' 'PRU' 'PSX' 'SYY' 'T' 'TECD' 'TGT' 'TJX' 'TSN' 'UAL'
#  'UNH' 'UPS' 'VLO' 'VZ' 'WBA' 'WFC' 'WMT' 'XOM']

# %%
tech_stocks = ['AAPL', 'AMZN', 'CSCO', 'FB', 'GOOGL', 'HPQ', 'IBM', 'INTC', 'MSFT', 'ORCL']
dftech = df[df['ticker'].isin(tech_stocks)]
dftech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359 entries, 36 to 1983
# Data columns (total 63 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ticker                            359 non-null    object
#  1   date                              359 non-null    datetime64[ns]
#  2   commonstocksharesissued           278 non-null    float64
#  3   assetscurrent                     359 non-null    float64
#  4   accountspayablecurrent            359 non-null    float64
#  5   commonstockvalue                  83 non-null     float64
#  6   liabilities                       203 non-null    float64
#  7   liabilitiesandstockholdersequity  359 non-null    float64
#  8   stockholdersequity                359 non-null    float64
#  9   earningspersharebasic             359 non-null    float64
#  10  netincomeloss                     359 non-null    float64
#  11  profitloss                        160 non-null    float64
#  12  costofgoodssold                   152 non-null    float64
#  13  costsandexpenses                  176 non-null    float64
#  14  cash                              148 non-null    float64
#  15  notespayable                      36 non-null     float64
#  16  preferredstockvalue               7 non-null      float64
#  17  depreciation                      254 non-null    float64
#  18  operatingexpenses                 199 non-null    float64
#  19  revenues                          218 non-null    float64
#  20  land                              76 non-null     float64
#  21  accountsreceivablenet             40 non-null     float64
#  22  deferredrevenue                   198 non-null    float64
#  23  grossprofit                       247 non-null    float64
#  24  sharesissued                      58 non-null     float64
#  25  accruedincometaxes                0 non-null      float64
#  26  sharesoutstanding                 37 non-null     float64
#  27  borrowedfunds                     0 non-null      float64
#  28  inventorygross                    0 non-null      float64
#  29  commercialpaper                   193 non-null    float64
#  30  dividends                         39 non-null     float64
#  31  commonstocknoparvalue             0 non-null      float64
#  32  costofservices                    151 non-null    float64
#  33  debtcurrent                       205 non-null    float64
#  34  accruedinsurancecurrent           0 non-null      float64
#  35  officerscompensation              0 non-null      float64
#  36  salariesandwages                  39 non-null     float64
#  37  interestanddebtexpense            0 non-null      float64
#  38  convertibledebt                   14 non-null     float64
#  39  operatingcycle                    0 non-null      object
#  40  open                              358 non-null    float64
#  41  high                              358 non-null    float64
#  42  low                               358 non-null    float64
#  43  close                             358 non-null    float64
#  44  close_adjusted                    358 non-null    float64
#  45  volume                            358 non-null    float64
#  46  split_coefficient                 358 non-null    float64
#  47  date_minus1                       314 non-null    datetime64[ns]
#  48  open_minus1                       314 non-null    float64
#  49  high_minus1                       314 non-null    float64
#  50  low_minus1                        314 non-null    float64
#  51  close_minus1                      314 non-null    float64
#  52  close_adj_minus1                  314 non-null    float64
#  53  volume_minus1                     314 non-null    float64
#  54  split_coef_minus1                 314 non-null    float64
#  55  date_plus1                        274 non-null    datetime64[ns]
#  56  open_plus1                        274 non-null    float64
#  57  high_plus1                        274 non-null    float64
#  58  low_plus1                         274 non-null    float64
#  59  close_plus1                       274 non-null    float64
#  60  close_adj_plus1                   274 non-null    float64
#  61  volume_plus1                      274 non-null    float64
#  62  split_coef_plus1                  274 non-null    float64
# dtypes: datetime64[ns](3), float64(58), object(2)
# memory usage: 179.5+ KB

# %%
dftech.groupby('ticker').revenues.count()
# Out:
# ticker
# AAPL      5
# AMZN      5
# CSCO     36
# FB       28
# GOOGL    14
# HPQ      38
# IBM      40
# INTC      1
# MSFT     12
# ORCL     39
# Name: revenues, dtype: int64

# %%
dftech.groupby('ticker').date.count() # for comparison, total number of records per ticker
# Out:
# ticker
# AAPL     39
# AMZN     40
# CSCO     40
# FB       28
# GOOGL    14
# HPQ      38
# IBM      40
# INTC     39
# MSFT     42
# ORCL     39
# Name: date, dtype: int64

# %%
# most complete revenues data
tech_revenues = ['CSCO', 'FB', 'GOOGL', 'HPQ', 'IBM', 'ORCL']
df_tech_rev = df[df['ticker'].isin(tech_revenues)]
df_tech_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 713 to 1983
# Data columns (total 63 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ticker                            199 non-null    object
#  1   date                              199 non-null    datetime64[ns]
#  2   commonstocksharesissued           160 non-null    float64
#  3   assetscurrent                     199 non-null    float64
#  4   accountspayablecurrent            199 non-null    float64
#  5   commonstockvalue                  19 non-null     float64
#  6   liabilities                       122 non-null    float64
#  7   liabilitiesandstockholdersequity  199 non-null    float64
#  8   stockholdersequity                199 non-null    float64
#  9   earningspersharebasic             199 non-null    float64
#  10  netincomeloss                     199 non-null    float64
#  11  profitloss                        124 non-null    float64
#  12  costofgoodssold                   112 non-null    float64
#  13  costsandexpenses                  119 non-null    float64
#  14  cash                              20 non-null     float64
#  15  notespayable                      0 non-null      float64
#  16  preferredstockvalue               7 non-null      float64
#  17  depreciation                      139 non-null    float64
#  18  operatingexpenses                 78 non-null     float64
#  19  revenues                          195 non-null    float64
#  20  land                              37 non-null     float64
#  21  accountsreceivablenet             0 non-null      float64
#  22  deferredrevenue                   119 non-null    float64
#  23  grossprofit                       119 non-null    float64
#  24  sharesissued                      51 non-null     float64
#  25  accruedincometaxes                0 non-null      float64
#  26  sharesoutstanding                 0 non-null      float64
#  27  borrowedfunds                     0 non-null      float64
#  28  inventorygross                    0 non-null      float64
#  29  commercialpaper                   79 non-null     float64
#  30  dividends                         0 non-null      float64
#  31  commonstocknoparvalue             0 non-null      float64
#  32  costofservices                    151 non-null    float64
#  33  debtcurrent                       166 non-null    float64
#  34  accruedinsurancecurrent           0 non-null      float64
#  35  officerscompensation              0 non-null      float64
#  36  salariesandwages                  39 non-null     float64
#  37  interestanddebtexpense            0 non-null      float64
#  38  convertibledebt                   0 non-null      float64
#  39  operatingcycle                    0 non-null      object
#  40  open                              198 non-null    float64
#  41  high                              198 non-null    float64
#  42  low                               198 non-null    float64
#  43  close                             198 non-null    float64
#  44  close_adjusted                    198 non-null    float64
#  45  volume                            198 non-null    float64
#  46  split_coefficient                 198 non-null    float64
#  47  date_minus1                       175 non-null    datetime64[ns]
#  48  open_minus1                       175 non-null    float64
#  49  high_minus1                       175 non-null    float64
#  50  low_minus1                        175 non-null    float64
#  51  close_minus1                      175 non-null    float64
#  52  close_adj_minus1                  175 non-null    float64
#  53  volume_minus1                     175 non-null    float64
#  54  split_coef_minus1                 175 non-null    float64
#  55  date_plus1                        171 non-null    datetime64[ns]
#  56  open_plus1                        171 non-null    float64
#  57  high_plus1                        171 non-null    float64
#  58  low_plus1                         171 non-null    float64
#  59  close_plus1                       171 non-null    float64
#  60  close_adj_plus1                   171 non-null    float64
#  61  volume_plus1                      171 non-null    float64
#  62  split_coef_plus1                  171 non-null    float64
# dtypes: datetime64[ns](3), float64(58), object(2)
# memory usage: 99.5+ KB

# %%
# drop null columns
df_tech_rev = df_tech_rev.dropna(axis='columns', how='all')

# %%
# check for split adjustments
fig, axs = plt.subplots(2, sharex=True, figsize=(12, 9))
fig.suptitle('Close vs Split-Adjusted')
for key, grp in df_tech_rev.groupby(['ticker']):
    axs[0].plot(grp['date'], grp['close'], label=key)
    axs[1].plot(grp['date'], grp['close_adjusted'], label=key)
    # credit: https://stackoverflow.com/questions/41494942/pandas-dataframe-groupby-plot
axs[0].ylabel = 'Close'
axs[1].ylabel = 'Adjusted Close'
plt.xlabel = 'Date'
axs[0].legend()
axs[1].legend()
plt.show()

# %%
# doesn't look like there were any big split events. How's the heatmap?
corrmap = df_tech_rev.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(round(corrmap,2), ax=ax, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
df_tech_rev.split_coefficient.unique()
# Out:
# array([ 1., nan])

# %%
df_tech_rev.split_coef_minus1.unique()
# Out:
# array([ 1., nan])

# %%
df_tech_rev.split_coef_plus1.unique()
# Out:
# array([ 1., nan])

# %%
# drop split coefficient, still not informational
dropcols = ['split_coefficient', 'split_coef_minus1', 'split_coef_plus1']
df_tech_rev = df_tech_rev.drop(dropcols, axis=1)

# %% [markdown]
# #### Try statistical tests (normality; histograms)

# %%
df_tr_numeric = df_tech_rev.select_dtypes(include=np.float64)
df_tr_numeric.shape
# Out:
# (199, 43)

# %%
# axes credit: https://stackoverflow.com/questions/46862861/what-does-axes-flat-in-matplotlib-do
n_cols = 4
n_rows = int(round(df_tr_numeric.shape[1]/n_cols, 0))
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(12, 9))
n_bins = 30

for i, ax in enumerate(axes.flat):
    if i in range(df_tr_numeric.shape[1]):
        ax.hist(df_tr_numeric.iloc[:,i], bins=n_bins)
        ax.xlabel = df_tr_numeric.columns[i]
        # ax.ylabel = 'Count'
   
# fig.tight_layout
plt.show()

# %% [markdown]
# So... even with multiple similar-sector companies, 43 tiny unlabeled plots don't look normal at all.
# Also I would probably do better to group these by columns with similar data ranges, but I don't want to spend all week on this.

# %%
# normality testing credit: https://machinelearningmastery.com/a-gentle-introduction-to-normality-tests-in-python/
# Shapiro-Wilk test
for col in df_tr_numeric.columns:
    print(col)
    stat, p = stats.shapiro(df_tr_numeric[col].notnull())
    print('Statistic=%.3f, p=%.3f' % (stat, p))
    # interpret
    alpha = 0.05
    if p > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
    else:
        print('Sample does not look Gaussian (reject H0)')
# Out:
# commonstocksharesissued
# Statistics=0.485, p=0.000
# Sample does not look Gaussian (reject H0)
# assetscurrent
# Statistics=1.000, p=1.000
# Sample looks Gaussian (fail to reject H0)
# accountspayablecurrent
# Statistics=1.000, p=1.000
# Sample looks Gaussian (fail to reject H0)
# commonstockvalue
# Statistics=0.333, p=0.000
# Sample does not look Gaussian (reject H0)
# liabilities
# Statistics=0.618, p=0.000
# Sample does not look Gaussian (reject H0)
# liabilitiesandstockholdersequity
# Statistics=1.000, p=1.000
# Sample looks Gaussian (fail to reject H0)
# stockholdersequity
# Statistics=1.000, p=1.000
# Sample looks Gaussian (fail to reject H0)
# earningspersharebasic
# Statistics=1.000, p=1.000
# Sample looks Gaussian (fail to reject H0)
# netincomeloss
# Statistics=1.000, p=1.000
# Sample looks Gaussian (fail to reject H0)
# profitloss
# Statistics=0.614, p=0.000
# Sample does not look Gaussian (reject H0)
# costofgoodssold
# Statistics=0.631, p=0.000
# Sample does not look Gaussian (reject H0)
# costsandexpenses
# Statistics=0.622, p=0.000
# Sample does not look Gaussian (reject H0)
# cash
# Statistics=0.343, p=0.000
# Sample does not look Gaussian (reject H0)
# preferredstockvalue
# Statistics=0.178, p=0.000
# Sample does not look Gaussian (reject H0)
# depreciation
# Statistics=0.576, p=0.000
# Sample does not look Gaussian (reject H0)
# operatingexpenses
# Statistics=0.619, p=0.000
# Sample does not look Gaussian (reject H0)
# revenues
# Statistics=0.121, p=0.000
# Sample does not look Gaussian (reject H0)
# land
# Statistics=0.473, p=0.000
# Sample does not look Gaussian (reject H0)
# deferredrevenue
# Statistics=0.622, p=0.000
# Sample does not look Gaussian (reject H0)
# grossprofit
# Statistics=0.622, p=0.000
# Sample does not look Gaussian (reject H0)
# sharesissued
# Statistics=0.544, p=0.000
# Sample does not look Gaussian (reject H0)
# commercialpaper
# Statistics=0.621, p=0.000
# Sample does not look Gaussian (reject H0)
# costofservices
# Statistics=0.531, p=0.000
# Sample does not look Gaussian (reject H0)
# debtcurrent
# Statistics=0.448, p=0.000
# Sample does not look Gaussian (reject H0)
# salariesandwages
# Statistics=0.485, p=0.000
# Sample does not look Gaussian (reject H0)
# open
# Statistics=0.044, p=0.000
# Sample does not look Gaussian (reject H0)
# high
# Statistics=0.044, p=0.000
# Sample does not look Gaussian (reject H0)
# low
# Statistics=0.044, p=0.000
# Sample does not look Gaussian (reject H0)
# close
# Statistics=0.044, p=0.000
# Sample does not look Gaussian (reject H0)
# close_adjusted
# Statistics=0.044, p=0.000
# Sample does not look Gaussian (reject H0)
# volume
# Statistics=0.044, p=0.000
# Sample does not look Gaussian (reject H0)
# open_minus1
# Statistics=0.380, p=0.000
# Sample does not look Gaussian (reject H0)
# high_minus1
# Statistics=0.380, p=0.000
# Sample does not look Gaussian (reject H0)
# low_minus1
# Statistics=0.380, p=0.000
# Sample does not look Gaussian (reject H0)
# close_minus1
# Statistics=0.380, p=0.000
# Sample does not look Gaussian (reject H0)
# close_adj_minus1
# Statistics=0.380, p=0.000
# Sample does not look Gaussian (reject H0)
# volume_minus1
# Statistics=0.380, p=0.000
# Sample does not look Gaussian (reject H0)
# open_plus1
# Statistics=0.412, p=0.000
# Sample does not look Gaussian (reject H0)
# high_plus1
# Statistics=0.412, p=0.000
# Sample does not look Gaussian (reject H0)
# low_plus1
# Statistics=0.412, p=0.000
# Sample does not look Gaussian (reject H0)
# close_plus1
# Statistics=0.412, p=0.000
# Sample does not look Gaussian (reject H0)
# close_adj_plus1
# Statistics=0.412, p=0.000
# Sample does not look Gaussian (reject H0)
# volume_plus1
# Statistics=0.412, p=0.000
# Sample does not look Gaussian (reject H0)
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "

# %% [markdown]
# I am suspicious of the columns where the "statistic" and p are both 1.000.
# - assetscurrent
# - accountspayablecurrent
# - liabilitiesandstockholdersequity
# - stockholdersequity
# - earningspersharebasic
# - netincomeloss
#
# Let's see what the other tests say. I might want to run these columns through testing without the .notnull() before I make a firm decision.

# %%
# D’Agostino’s K^2 Test
for col in df_tr_numeric.columns:
    print(col)
    stat, p = stats.normaltest(df_tr_numeric[col].notnull())
    print('Statistic=%.3f, p=%.3f' % (stat, p))
    # interpret
    alpha = 0.05
    if p > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
    else:
        print('Sample does not look Gaussian (reject H0)')
# Out:
# commonstocksharesissued
# Statistic=48.638, p=0.000
# Sample does not look Gaussian (reject H0)
# assetscurrent
# Statistic=730.133, p=0.000
# Sample does not look Gaussian (reject H0)
# accountspayablecurrent
# Statistic=730.133, p=0.000
# Sample does not look Gaussian (reject H0)
# commonstockvalue
# Statistic=125.330, p=0.000
# Sample does not look Gaussian (reject H0)
# liabilities
# Statistic=1346.033, p=0.000
# Sample does not look Gaussian (reject H0)
# liabilitiesandstockholdersequity
# Statistic=730.133, p=0.000
# Sample does not look Gaussian (reject H0)
# stockholdersequity
# Statistic=730.133, p=0.000
# Sample does not look Gaussian (reject H0)
# earningspersharebasic
# Statistic=730.133, p=0.000
# Sample does not look Gaussian (reject H0)
# netincomeloss
# Statistic=730.133, p=0.000
# Sample does not look Gaussian (reject H0)
# profitloss
# Statistic=1437.323, p=0.000
# Sample does not look Gaussian (reject H0)
# costofgoodssold
# Statistic=1135.061, p=0.000
# Sample does not look Gaussian (reject H0)
# costsandexpenses
# Statistic=1252.647, p=0.000
# Sample does not look Gaussian (reject H0)
# cash
# Statistic=119.734, p=0.000
# Sample does not look Gaussian (reject H0)
# preferredstockvalue
# Statistic=231.577, p=0.000
# Sample does not look Gaussian (reject H0)
# depreciation
# Statistic=145.331, p=0.000
# Sample does not look Gaussian (reject H0)
# operatingexpenses
# Statistic=1310.326, p=0.000
# Sample does not look Gaussian (reject H0)
# revenues
# Statistic=290.496, p=0.000
# Sample does not look Gaussian (reject H0)
# land
# Statistic=53.493, p=0.000
# Sample does not look Gaussian (reject H0)
# deferredrevenue
# Statistic=1252.647, p=0.000
# Sample does not look Gaussian (reject H0)
# grossprofit
# Statistic=1252.647, p=0.000
# Sample does not look Gaussian (reject H0)
# sharesissued
# Statistic=41.586, p=0.000
# Sample does not look Gaussian (reject H0)
# commercialpaper
# Statistic=1279.493, p=0.000
# Sample does not look Gaussian (reject H0)
# costofservices
# Statistic=37.974, p=0.000
# Sample does not look Gaussian (reject H0)
# debtcurrent
# Statistic=65.066, p=0.000
# Sample does not look Gaussian (reject H0)
# salariesandwages
# Statistic=48.638, p=0.000
# Sample does not look Gaussian (reject H0)
# open
# Statistic=441.413, p=0.000
# Sample does not look Gaussian (reject H0)
# high
# Statistic=441.413, p=0.000
# Sample does not look Gaussian (reject H0)
# low
# Statistic=441.413, p=0.000
# Sample does not look Gaussian (reject H0)
# close
# Statistic=441.413, p=0.000
# Sample does not look Gaussian (reject H0)
# close_adjusted
# Statistic=441.413, p=0.000
# Sample does not look Gaussian (reject H0)
# volume
# Statistic=441.413, p=0.000
# Sample does not look Gaussian (reject H0)
# open_minus1
# Statistic=99.729, p=0.000
# Sample does not look Gaussian (reject H0)
# high_minus1
# Statistic=99.729, p=0.000
# Sample does not look Gaussian (reject H0)
# low_minus1
# Statistic=99.729, p=0.000
# Sample does not look Gaussian (reject H0)
# close_minus1
# Statistic=99.729, p=0.000
# Sample does not look Gaussian (reject H0)
# close_adj_minus1
# Statistic=99.729, p=0.000
# Sample does not look Gaussian (reject H0)
# volume_minus1
# Statistic=99.729, p=0.000
# Sample does not look Gaussian (reject H0)
# open_plus1
# Statistic=82.781, p=0.000
# Sample does not look Gaussian (reject H0)
# high_plus1
# Statistic=82.781, p=0.000
# Sample does not look Gaussian (reject H0)
# low_plus1
# Statistic=82.781, p=0.000
# Sample does not look Gaussian (reject H0)
# close_plus1
# Statistic=82.781, p=0.000
# Sample does not look Gaussian (reject H0)
# close_adj_plus1
# Statistic=82.781, p=0.000
# Sample does not look Gaussian (reject H0)
# volume_plus1
# Statistic=82.781, p=0.000
# Sample does not look Gaussian (reject H0)

# %% [markdown]
# No normals here! I'm in good company! Although my suspicious columns from before all have the same statistic number.

# %%
# Anderson-Darling Test
for col in df_tr_numeric.columns:
    print(col)
    result = stats.anderson(df_tr_numeric[col].notnull())
    print('Statistic=%.3f' % result.statistic)
    # interpret
    for i in range(len(result.critical_values)):
        sl, cv = result.significance_level[i], result.critical_values[i]
        if result.statistic < result.critical_values[i]:
            print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
        else:
            print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
# Out:
# commonstocksharesissued
# Statistic=53.336
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# assetscurrent
# Statistic=nan
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# accountspayablecurrent
# Statistic=nan
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# commonstockvalue
# Statistic=66.067
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# liabilities
# Statistic=38.035
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# liabilitiesandstockholdersequity
# Statistic=nan
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# stockholdersequity
# Statistic=nan
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# earningspersharebasic
# Statistic=nan
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# netincomeloss
# Statistic=nan
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# profitloss
# Statistic=38.491
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# costofgoodssold
# Statistic=36.339
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# costsandexpenses
# Statistic=37.424
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# cash
# Statistic=65.405
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# preferredstockvalue
# Statistic=73.546
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# depreciation
# Statistic=43.160
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# operatingexpenses
# Statistic=37.821
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# revenues
# Statistic=75.147
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# land
# Statistic=54.509
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# deferredrevenue
# Statistic=37.424
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# grossprofit
# Statistic=37.424
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# sharesissued
# Statistic=47.017
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# commercialpaper
# Statistic=37.617
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# costofservices
# Statistic=48.474
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# debtcurrent
# Statistic=56.944
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# salariesandwages
# Statistic=53.336
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# open
# Statistic=76.520
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# high
# Statistic=76.520
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# low
# Statistic=76.520
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# close
# Statistic=76.520
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# close_adjusted
# Statistic=76.520
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# volume
# Statistic=76.520
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# open_minus1
# Statistic=62.753
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# high_minus1
# Statistic=62.753
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# low_minus1
# Statistic=62.753
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# close_minus1
# Statistic=62.753
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# close_adj_minus1
# Statistic=62.753
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# volume_minus1
# Statistic=62.753
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# open_plus1
# Statistic=60.128
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# high_plus1
# Statistic=60.128
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# low_plus1
# Statistic=60.128
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# close_plus1
# Statistic=60.128
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# close_adj_plus1
# Statistic=60.128
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# volume_plus1
# Statistic=60.128
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s

# %% [markdown]
# Trouble with the same group of columns. Let's see what happens if I test them by themselves. The first time I tried the Shapiro test, I didn't realize I needed to drop nulls, and I got different results on the few columns that have no nulls.

# %%
coltest = ['assetscurrent', 'accountspayablecurrent', 'liabilitiesandstockholdersequity', 
           'stockholdersequity', 'earningspersharebasic', 'netincomeloss']
df_coltest = df_tr_numeric[coltest]
df_coltest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 713 to 1983
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   assetscurrent                     199 non-null    float64
#  1   accountspayablecurrent            199 non-null    float64
#  2   liabilitiesandstockholdersequity  199 non-null    float64
#  3   stockholdersequity                199 non-null    float64
#  4   earningspersharebasic             199 non-null    float64
#  5   netincomeloss                     199 non-null    float64
# dtypes: float64(6)
# memory usage: 20.9 KB

# %%
# rerun tests without .notnull for columns with no null values
for col in df_coltest.columns:
    print(col)
    stat, p = stats.shapiro(df_coltest[col])
    # interpret Shapiro
    alpha = 0.05
    if p > alpha:
        print('Shapiro Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample looks Gaussian (fail to reject H0)')
    else:
        print('Shapiro Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample does not look Gaussian (reject H0)')
    stat, p = stats.normaltest(df_coltest[col])
    # interpret D'Agostino
    alpha = 0.05
    if p > alpha:
        print('D\'Agostino Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample looks Gaussian (fail to reject H0)')
    else:
        print('D\'Agostino Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample does not look Gaussian (reject H0)')
    result = stats.anderson(df_coltest[col])
    print('Anderson Statistic=%.3f' % result.statistic)
    # interpret Anderson
    for i in range(len(result.critical_values)):
        sl, cv = result.significance_level[i], result.critical_values[i]
        if result.statistic < result.critical_values[i]:
            print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
        else:
            print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
# Out:
# assetscurrent
# Shapiro Statistic=0.925, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=28.829, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=4.876
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# accountspayablecurrent
# Shapiro Statistic=0.791, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=27.451, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=16.709
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# liabilitiesandstockholdersequity
# Shapiro Statistic=0.948, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=2.636, p=0.268 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=4.179
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# stockholdersequity
# Shapiro Statistic=0.920, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=34.418, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=2.852
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# earningspersharebasic
# Shapiro Statistic=0.593, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=169.439, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=27.999
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# netincomeloss
# Shapiro Statistic=0.753, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=107.548, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=16.427
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.900, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)

# %% [markdown]
# Yup, for some reason results are different when I don't try to drop nulls that don't exist in these columns. And nothing is normal.

# %% [markdown]
# #### Try the linear regressions

# %% [markdown]
# I'll try one, or at least plot one, since it's pretty clear that my data is not normal.

# %%
sns.regplot(x='revenues', y='close', data=df_tr_numeric)
# Out:
# <AxesSubplot:xlabel='revenues', ylabel='close'>

# %% [markdown]
# hm. Is that the Google prices throwing everything else off?

# %%
test = df_tech_rev[df_tech_rev['ticker'] != 'GOOGL']
test.ticker.unique()
test = test.select_dtypes(include=np.float64)

# %%
# rerun normality tests without Google
for col in test.columns:
    print(col)
    stat, p = stats.shapiro(test[col].notnull())
    # interpret Shapiro
    alpha = 0.05
    if p > alpha:
        print('Shapiro Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample looks Gaussian (fail to reject H0)')
    else:
        print('Shapiro Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample does not look Gaussian (reject H0)')
    stat, p = stats.normaltest(test[col].notnull())
    # interpret D'Agostino
    alpha = 0.05
    if p > alpha:
        print('D\'Agostino Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample looks Gaussian (fail to reject H0)')
    else:
        print('D\'Agostino Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample does not look Gaussian (reject H0)')
    result = stats.anderson(test[col].notnull())
    print('Anderson Statistic=%.3f' % result.statistic)
    # interpret Anderson
    for i in range(len(result.critical_values)):
        sl, cv = result.significance_level[i], result.critical_values[i]
        if result.statistic < result.critical_values[i]:
            print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
        else:
            print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
# Out:
# commonstocksharesissued
# Shapiro Statistic=0.501, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=40.095, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=48.019
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# assetscurrent
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=696.416, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# accountspayablecurrent
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=696.416, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# commonstockvalue
# Shapiro Statistic=0.264, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=157.124, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=65.082
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# liabilities
# Shapiro Statistic=0.626, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=1147.904, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=34.319
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# liabilitiesandstockholdersequity
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=696.416, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# stockholdersequity
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=696.416, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# earningspersharebasic
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=696.416, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# netincomeloss
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=696.416, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# profitloss
# Shapiro Statistic=0.616, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=1326.182, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=35.476
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# costofgoodssold
# Shapiro Statistic=0.620, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=1248.019, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=35.049
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# costsandexpenses
# Shapiro Statistic=0.630, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=1101.189, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=33.881
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# cash
# Shapiro Statistic=0.357, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=105.046, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=59.864
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# preferredstockvalue
# Shapiro Statistic=0.187, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=210.837, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=68.091
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# depreciation
# Shapiro Statistic=0.537, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=36.415, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=44.375
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# operatingexpenses
# Shapiro Statistic=0.627, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=1130.297, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=34.162
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# revenues
# Shapiro Statistic=0.128, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=266.358, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=69.716
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# land
# Shapiro Statistic=0.490, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=43.942, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=49.146
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# deferredrevenue
# Shapiro Statistic=0.606, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=1753.813, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=36.730
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# grossprofit
# Shapiro Statistic=0.606, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=1753.813, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=36.730
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# sharesissued
# Shapiro Statistic=0.507, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=38.528, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=47.470
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# commercialpaper
# Shapiro Statistic=0.618, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=1283.831, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=35.257
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# costofservices
# Shapiro Statistic=0.471, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=51.215, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=50.901
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# debtcurrent
# Shapiro Statistic=0.428, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=70.253, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=54.620
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# salariesandwages
# Shapiro Statistic=0.501, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=40.095, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=48.019
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# open
# Shapiro Statistic=0.047, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=408.141, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=71.108
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# high
# Shapiro Statistic=0.047, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=408.141, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=71.108
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# low
# Shapiro Statistic=0.047, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=408.141, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=71.108
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# close
# Shapiro Statistic=0.047, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=408.141, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=71.108
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# close_adjusted
# Shapiro Statistic=0.047, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=408.141, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=71.108
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# volume
# Shapiro Statistic=0.047, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=408.141, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=71.108
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# open_minus1
# Shapiro Statistic=0.395, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=86.147, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=57.217
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# high_minus1
# Shapiro Statistic=0.395, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=86.147, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=57.217
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# low_minus1
# Shapiro Statistic=0.395, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=86.147, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=57.217
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# close_minus1
# Shapiro Statistic=0.395, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=86.147, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=57.217
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# close_adj_minus1
# Shapiro Statistic=0.395, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=86.147, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=57.217
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# volume_minus1
# Shapiro Statistic=0.395, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=86.147, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=57.217
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# open_plus1
# Shapiro Statistic=0.404, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=81.917, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=56.562
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# high_plus1
# Shapiro Statistic=0.404, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=81.917, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=56.562
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# low_plus1
# Shapiro Statistic=0.404, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=81.917, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=56.562
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# close_plus1
# Shapiro Statistic=0.404, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=81.917, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=56.562
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# close_adj_plus1
# Shapiro Statistic=0.404, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=81.917, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=56.562
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# volume_plus1
# Shapiro Statistic=0.404, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=81.917, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=56.562
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s

# %%
test_coltest = test[coltest]
test_coltest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185 entries, 713 to 1983
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   assetscurrent                     185 non-null    float64
#  1   accountspayablecurrent            185 non-null    float64
#  2   liabilitiesandstockholdersequity  185 non-null    float64
#  3   stockholdersequity                185 non-null    float64
#  4   earningspersharebasic             185 non-null    float64
#  5   netincomeloss                     185 non-null    float64
# dtypes: float64(6)
# memory usage: 10.1 KB

# %%
# re-rerun tests without .notnull for columns with no null values
for col in df_coltest.columns:
    print(col)
    stat, p = stats.shapiro(test_coltest[col])
    # interpret Shapiro
    alpha = 0.05
    if p > alpha:
        print('Shapiro Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample looks Gaussian (fail to reject H0)')
    else:
        print('Shapiro Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample does not look Gaussian (reject H0)')
    stat, p = stats.normaltest(test_coltest[col])
    # interpret D'Agostino
    alpha = 0.05
    if p > alpha:
        print('D\'Agostino Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample looks Gaussian (fail to reject H0)')
    else:
        print('D\'Agostino Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample does not look Gaussian (reject H0)')
    result = stats.anderson(test_coltest[col])
    print('Anderson Statistic=%.3f' % result.statistic)
    # interpret Anderson
    for i in range(len(result.critical_values)):
        sl, cv = result.significance_level[i], result.critical_values[i]
        if result.statistic < result.critical_values[i]:
            print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
        else:
            print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
# Out:
# assetscurrent
# Shapiro Statistic=0.949, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=2.798, p=0.247 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=4.198
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# accountspayablecurrent
# Shapiro Statistic=0.786, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=27.842, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=16.325
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# liabilitiesandstockholdersequity
# Shapiro Statistic=0.889, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=20.975, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.339
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# stockholdersequity
# Shapiro Statistic=0.955, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=16.004, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=2.732
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# earningspersharebasic
# Shapiro Statistic=0.696, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=100.558, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=20.035
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)
# netincomeloss
# Shapiro Statistic=0.803, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=56.791, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=14.273
# 15.000: 0.564, data does not look normal (reject H0)
# 10.000: 0.643, data does not look normal (reject H0)
# 5.000: 0.771, data does not look normal (reject H0)
# 2.500: 0.899, data does not look normal (reject H0)
# 1.000: 1.070, data does not look normal (reject H0)

# %% [markdown]
# Still no normals here! Just for kicks, one regplot...

# %%
sns.regplot(x='revenues', y='close', data=test)
# Out:
# <AxesSubplot:xlabel='revenues', ylabel='close'>

# %% [markdown]
# If anything, the Google outliers made the first regplot look better fitted because they threw the scale off so far.

# %% [markdown]
# I'm feeling stubborn today. I will ask if my data seem normal when taken one stock at a time.

# %%
test2 = df_tech_rev[df_tech_rev['ticker'] != 'GOOGL']
test2.ticker.unique()
# Out:
# array(['CSCO', 'FB', 'HPQ', 'IBM', 'ORCL'], dtype=object)

# %%
dflist = []
for t in test2.ticker.unique():
    df = test2[test2['ticker'] == t]
    df = df.select_dtypes(include=np.float64)
    dflist.append(df)
    
for df in dflist:
    for col in df.columns:
        print(col)
        if df[col].isnull().any():
            stat, p = stats.shapiro(df[col].notnull())
            # interpret Shapiro
            alpha = 0.05
            if p > alpha:
                print('Shapiro Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample looks Gaussian (fail to reject H0)')
            else:
                print('Shapiro Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample does not look Gaussian (reject H0)')
            stat, p = stats.normaltest(df[col].notnull())
            # interpret D'Agostino
            alpha = 0.05
            if p > alpha:
                print('D\'Agostino Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample looks Gaussian (fail to reject H0)')
            else:
                print('D\'Agostino Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample does not look Gaussian (reject H0)')
            result = stats.anderson(df[col].notnull())
            print('Anderson Statistic=%.3f' % result.statistic)
            # interpret Anderson
            for i in range(len(result.critical_values)):
                sl, cv = result.significance_level[i], result.critical_values[i]
                if result.statistic < result.critical_values[i]:
                    print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
                else:
                    print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
        else:
            stat, p = stats.shapiro(df[col])
            # interpret Shapiro
            alpha = 0.05
            if p > alpha:
                print('Shapiro Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample looks Gaussian (fail to reject H0)')
            else:
                print('Shapiro Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample does not look Gaussian (reject H0)')
            stat, p = stats.normaltest(df[col])
            # interpret D'Agostino
            alpha = 0.05
            if p > alpha:
                print('D\'Agostino Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample looks Gaussian (fail to reject H0)')
            else:
                print('D\'Agostino Statistic=%.3f, p=%.3f ' % (stat, p) + 'Sample does not look Gaussian (reject H0)')
            result = stats.anderson(df[col])
            print('Anderson Statistic=%.3f' % result.statistic)
            # interpret Anderson
            for i in range(len(result.critical_values)):
                sl, cv = result.significance_level[i], result.critical_values[i]
                if result.statistic < result.critical_values[i]:
                    print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
                else:
                    print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
# Out:
# commonstocksharesissued
# Shapiro Statistic=0.955, p=0.112 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=2.614, p=0.271 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.617
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data looks normal (fail to reject H0)
# 2.500: 0.847, data looks normal (fail to reject H0)
# 1.000: 1.007, data looks normal (fail to reject H0)
# assetscurrent
# Shapiro Statistic=0.958, p=0.141 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=3.216, p=0.200 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.470
# 15.000: 0.531, data looks normal (fail to reject H0)
# 10.000: 0.605, data looks normal (fail to reject H0)
# 5.000: 0.726, data looks normal (fail to reject H0)
# 2.500: 0.847, data looks normal (fail to reject H0)
# 1.000: 1.007, data looks normal (fail to reject H0)
# accountspayablecurrent
# Shapiro Statistic=0.788, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=17.412, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=3.291
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# commonstockvalue
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=397.295, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# liabilities
# Shapiro Statistic=0.937, p=0.028 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=2.598, p=0.273 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=1.128
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# liabilitiesandstockholdersequity
# Shapiro Statistic=0.794, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=19.237, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=2.623
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# stockholdersequity
# Shapiro Statistic=0.784, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=34.392, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=3.637
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# earningspersharebasic
# Shapiro Statistic=0.925, p=0.011 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=1.144, p=0.564 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=1.504
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# netincomeloss
# Shapiro Statistic=0.934, p=0.022 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=0.808, p=0.668 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=1.127
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# profitloss
# Shapiro Statistic=0.428, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=22.964, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=11.754
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# costofgoodssold
# Shapiro Statistic=0.859, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=5.414, p=0.067 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=2.528
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# costsandexpenses
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=397.295, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# cash
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=397.295, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# preferredstockvalue
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=397.295, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# depreciation
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=397.295, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# operatingexpenses
# Shapiro Statistic=0.847, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=27.850, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=2.237
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# revenues
# Shapiro Statistic=0.345, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=38.528, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=13.091
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# land
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=397.295, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# deferredrevenue
# Shapiro Statistic=0.921, p=0.009 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=7.669, p=0.022 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.219
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# grossprofit
# Shapiro Statistic=0.906, p=0.003 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=6.708, p=0.035 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.062
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# sharesissued
# Shapiro Statistic=0.949, p=0.070 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=3.114, p=0.211 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.694
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data looks normal (fail to reject H0)
# 2.500: 0.847, data looks normal (fail to reject H0)
# 1.000: 1.007, data looks normal (fail to reject H0)
# commercialpaper
# Shapiro Statistic=0.614, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=92.437, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.627
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# costofservices
# Shapiro Statistic=0.837, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=9.981, p=0.007 Sample does not look Gaussian (reject H0)
# Anderson Statistic=2.606
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# debtcurrent
# Shapiro Statistic=0.744, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=22.447, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=3.150
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# salariesandwages
# Shapiro Statistic=0.147, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=92.236, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=14.984
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# open
# Shapiro Statistic=0.883, p=0.001 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=8.001, p=0.018 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.670
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# high
# Shapiro Statistic=0.882, p=0.001 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=7.909, p=0.019 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.691
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# low
# Shapiro Statistic=0.884, p=0.001 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=7.893, p=0.019 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.645
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# close
# Shapiro Statistic=0.884, p=0.001 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=7.937, p=0.019 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.635
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# close_adjusted
# Shapiro Statistic=0.876, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=7.247, p=0.027 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.741
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# volume
# Shapiro Statistic=0.800, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=15.870, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=2.984
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# open_minus1
# Shapiro Statistic=0.428, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=22.964, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=11.754
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# high_minus1
# Shapiro Statistic=0.428, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=22.964, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=11.754
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# low_minus1
# Shapiro Statistic=0.428, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=22.964, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=11.754
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# close_minus1
# Shapiro Statistic=0.428, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=22.964, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=11.754
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# close_adj_minus1
# Shapiro Statistic=0.428, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=22.964, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=11.754
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# volume_minus1
# Shapiro Statistic=0.428, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=22.964, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=11.754
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# open_plus1
# Shapiro Statistic=0.147, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=92.236, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=14.984
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# high_plus1
# Shapiro Statistic=0.147, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=92.236, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=14.984
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# low_plus1
# Shapiro Statistic=0.147, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=92.236, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=14.984
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# close_plus1
# Shapiro Statistic=0.147, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=92.236, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=14.984
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# close_adj_plus1
# Shapiro Statistic=0.147, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=92.236, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=14.984
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# volume_plus1
# Shapiro Statistic=0.147, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=92.236, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=14.984
# 15.000: 0.531, data does not look normal (reject H0)
# 10.000: 0.605, data does not look normal (reject H0)
# 5.000: 0.726, data does not look normal (reject H0)
# 2.500: 0.847, data does not look normal (reject H0)
# 1.000: 1.007, data does not look normal (reject H0)
# commonstocksharesissued
# Shapiro Statistic=0.636, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=24.319, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=4.492
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# assetscurrent
# Shapiro Statistic=0.870, p=0.002 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=9.214, p=0.010 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.438
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# accountspayablecurrent
# Shapiro Statistic=0.814, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=9.993, p=0.007 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.900
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# 1.000: 0.983, data does not look normal (reject H0)
# commonstockvalue
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# liabilities
# Shapiro Statistic=0.813, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=22.706, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.480
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# liabilitiesandstockholdersequity
# Shapiro Statistic=0.934, p=0.079 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=5.231, p=0.073 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.572
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# stockholdersequity
# Shapiro Statistic=0.952, p=0.218 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=1.741, p=0.419 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.452
# 15.000: 0.518, data looks normal (fail to reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# earningspersharebasic
# Shapiro Statistic=0.789, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=14.090, p=0.001 Sample does not look Gaussian (reject H0)
# Anderson Statistic=2.158
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# netincomeloss
# Shapiro Statistic=0.574, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=26.667, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=5.143
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# profitloss
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# costofgoodssold
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# costsandexpenses
# Shapiro Statistic=0.859, p=0.001 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=12.150, p=0.002 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.144
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# cash
# Shapiro Statistic=0.568, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=8.147, p=0.017 Sample does not look Gaussian (reject H0)
# Anderson Statistic=6.120
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# preferredstockvalue
# Shapiro Statistic=0.541, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=7.072, p=0.029 Sample does not look Gaussian (reject H0)
# Anderson Statistic=6.574
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# depreciation
# Shapiro Statistic=0.361, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=30.230, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=9.001
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# operatingexpenses
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# revenues
# Shapiro Statistic=0.757, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=22.427, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=2.192
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# land
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# deferredrevenue
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# grossprofit
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# sharesissued
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# commercialpaper
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# costofservices
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# debtcurrent
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# salariesandwages
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=410.692, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# open
# Shapiro Statistic=0.936, p=0.090 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=6.757, p=0.034 Sample does not look Gaussian (reject H0)
# Anderson Statistic=0.495
# 15.000: 0.518, data looks normal (fail to reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# high
# Shapiro Statistic=0.936, p=0.088 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=6.576, p=0.037 Sample does not look Gaussian (reject H0)
# Anderson Statistic=0.490
# 15.000: 0.518, data looks normal (fail to reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# low
# Shapiro Statistic=0.937, p=0.094 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=6.651, p=0.036 Sample does not look Gaussian (reject H0)
# Anderson Statistic=0.480
# 15.000: 0.518, data looks normal (fail to reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# close
# Shapiro Statistic=0.937, p=0.091 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=6.476, p=0.039 Sample does not look Gaussian (reject H0)
# Anderson Statistic=0.480
# 15.000: 0.518, data looks normal (fail to reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# close_adjusted
# Shapiro Statistic=0.937, p=0.091 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=6.476, p=0.039 Sample does not look Gaussian (reject H0)
# Anderson Statistic=0.480
# 15.000: 0.518, data looks normal (fail to reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# volume
# Shapiro Statistic=0.675, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=38.106, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=2.918
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# open_minus1
# Shapiro Statistic=0.959, p=0.333 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=2.793, p=0.247 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.303
# 15.000: 0.518, data looks normal (fail to reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# high_minus1
# Shapiro Statistic=0.960, p=0.342 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=2.775, p=0.250 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.312
# 15.000: 0.518, data looks normal (fail to reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# low_minus1
# Shapiro Statistic=0.959, p=0.330 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=2.721, p=0.256 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.306
# 15.000: 0.518, data looks normal (fail to reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# close_minus1
# Shapiro Statistic=0.959, p=0.329 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=2.753, p=0.252 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.317
# 15.000: 0.518, data looks normal (fail to reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# close_adj_minus1
# Shapiro Statistic=0.959, p=0.329 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=2.753, p=0.252 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.317
# 15.000: 0.518, data looks normal (fail to reject H0)
# 10.000: 0.590, data looks normal (fail to reject H0)
# 5.000: 0.708, data looks normal (fail to reject H0)
# 2.500: 0.826, data looks normal (fail to reject H0)
# 1.000: 0.983, data looks normal (fail to reject H0)
# volume_minus1
# Shapiro Statistic=0.769, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=22.031, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=2.247
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# open_plus1
# Shapiro Statistic=0.508, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=9.162, p=0.010 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.097
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# high_plus1
# Shapiro Statistic=0.508, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=9.162, p=0.010 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.097
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# low_plus1
# Shapiro Statistic=0.508, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=9.162, p=0.010 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.097
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# close_plus1
# Shapiro Statistic=0.508, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=9.162, p=0.010 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.097
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# close_adj_plus1
# Shapiro Statistic=0.508, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=9.162, p=0.010 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.097
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# volume_plus1
# Shapiro Statistic=0.508, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=9.162, p=0.010 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.097
# 15.000: 0.518, data does not look normal (reject H0)
# 10.000: 0.590, data does not look normal (reject H0)
# 5.000: 0.708, data does not look normal (reject H0)
# 2.500: 0.826, data does not look normal (reject H0)
# 1.000: 0.983, data does not look normal (reject H0)
# commonstocksharesissued
# Shapiro Statistic=0.939, p=0.040 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=2.333, p=0.311 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.693
# 15.000: 0.529, data does not look normal (reject H0)
# 10.000: 0.603, data does not look normal (reject H0)
# 5.000: 0.723, data looks normal (fail to reject H0)
# 2.500: 0.844, data looks normal (fail to reject H0)
# 1.000: 1.004, data looks normal (fail to reject H0)
# assetscurrent
# Shapiro Statistic=0.725, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=27.336, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=5.032
# 15.000: 0.529, data does not look normal (reject H0)
# 10.000: 0.603, data does not look normal (reject H0)
# 5.000: 0.723, data does not look normal (reject H0)
# 2.500: 0.844, data does not look normal (reject H0)
# 1.000: 1.004, data does not look normal (reject H0)
# accountspayablecurrent
# Shapiro Statistic=0.937, p=0.035 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=5.027, p=0.081 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.718
# 15.000: 0.529, data does not look normal (reject H0)
# 10.000: 0.603, data does not look normal (reject H0)
# 5.000: 0.723, data looks normal (fail to reject H0)
# 2.500: 0.844, data looks normal (fail to reject H0)
# 1.000: 1.004, data looks normal (fail to reject H0)
# commonstockvalue
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=397.166, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.529, data does not look normal (reject H0)
# 10.000: 0.603, data does not look normal (reject H0)
# 5.000: 0.723, data does not look normal (reject H0)
# 2.500: 0.844, data does not look normal (reject H0)
# 1.000: 1.004, data does not look normal (reject H0)
# liabilities
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=397.166, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# ...
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# Anderson Statistic=nan
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# depreciation
# Shapiro Statistic=0.925, p=0.012 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=4.413, p=0.110 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.997
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data looks normal (fail to reject H0)
# operatingexpenses
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=397.154, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# revenues
# Shapiro Statistic=0.904, p=0.003 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=6.307, p=0.043 Sample does not look Gaussian (reject H0)
# Anderson Statistic=1.228
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# land
# Shapiro Statistic=0.233, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=63.745, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=14.008
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# deferredrevenue
# Shapiro Statistic=0.897, p=0.002 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=4.352, p=0.114 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=1.141
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# grossprofit
# Shapiro Statistic=0.503, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=38.340, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=9.413
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# sharesissued
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=397.154, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# commercialpaper
# Shapiro Statistic=0.596, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=29.707, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.893
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# costofservices
# Shapiro Statistic=0.851, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=5.755, p=0.056 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=2.161
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# debtcurrent
# Shapiro Statistic=0.700, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=31.270, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=3.675
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# salariesandwages
# Shapiro Statistic=1.000, p=1.000 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=397.154, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=nan
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# open
# Shapiro Statistic=0.983, p=0.822 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=1.189, p=0.552 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.185
# 15.000: 0.530, data looks normal (fail to reject H0)
# 10.000: 0.604, data looks normal (fail to reject H0)
# 5.000: 0.725, data looks normal (fail to reject H0)
# 2.500: 0.845, data looks normal (fail to reject H0)
# 1.000: 1.005, data looks normal (fail to reject H0)
# high
# Shapiro Statistic=0.981, p=0.756 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=1.498, p=0.473 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.207
# 15.000: 0.530, data looks normal (fail to reject H0)
# 10.000: 0.604, data looks normal (fail to reject H0)
# 5.000: 0.725, data looks normal (fail to reject H0)
# 2.500: 0.845, data looks normal (fail to reject H0)
# 1.000: 1.005, data looks normal (fail to reject H0)
# low
# Shapiro Statistic=0.983, p=0.798 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=1.474, p=0.478 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.192
# 15.000: 0.530, data looks normal (fail to reject H0)
# 10.000: 0.604, data looks normal (fail to reject H0)
# 5.000: 0.725, data looks normal (fail to reject H0)
# 2.500: 0.845, data looks normal (fail to reject H0)
# 1.000: 1.005, data looks normal (fail to reject H0)
# close
# Shapiro Statistic=0.982, p=0.779 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=1.500, p=0.472 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.192
# 15.000: 0.530, data looks normal (fail to reject H0)
# 10.000: 0.604, data looks normal (fail to reject H0)
# 5.000: 0.725, data looks normal (fail to reject H0)
# 2.500: 0.845, data looks normal (fail to reject H0)
# 1.000: 1.005, data looks normal (fail to reject H0)
# close_adjusted
# Shapiro Statistic=0.978, p=0.614 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=2.175, p=0.337 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.245
# 15.000: 0.530, data looks normal (fail to reject H0)
# 10.000: 0.604, data looks normal (fail to reject H0)
# 5.000: 0.725, data looks normal (fail to reject H0)
# 2.500: 0.845, data looks normal (fail to reject H0)
# 1.000: 1.005, data looks normal (fail to reject H0)
# volume
# Shapiro Statistic=0.954, p=0.111 Sample looks Gaussian (fail to reject H0)
# D'Agostino Statistic=4.007, p=0.135 Sample looks Gaussian (fail to reject H0)
# Anderson Statistic=0.457
# 15.000: 0.530, data looks normal (fail to reject H0)
# 10.000: 0.604, data looks normal (fail to reject H0)
# 5.000: 0.725, data looks normal (fail to reject H0)
# 2.500: 0.845, data looks normal (fail to reject H0)
# 1.000: 1.005, data looks normal (fail to reject H0)
# open_minus1
# Shapiro Statistic=0.497, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=12.359, p=0.002 Sample does not look Gaussian (reject H0)
# Anderson Statistic=10.140
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# high_minus1
# Shapiro Statistic=0.497, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=12.359, p=0.002 Sample does not look Gaussian (reject H0)
# Anderson Statistic=10.140
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# low_minus1
# Shapiro Statistic=0.497, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=12.359, p=0.002 Sample does not look Gaussian (reject H0)
# Anderson Statistic=10.140
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# close_minus1
# Shapiro Statistic=0.497, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=12.359, p=0.002 Sample does not look Gaussian (reject H0)
# Anderson Statistic=10.140
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# close_adj_minus1
# Shapiro Statistic=0.497, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=12.359, p=0.002 Sample does not look Gaussian (reject H0)
# Anderson Statistic=10.140
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# volume_minus1
# Shapiro Statistic=0.497, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=12.359, p=0.002 Sample does not look Gaussian (reject H0)
# Anderson Statistic=10.140
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# open_plus1
# Shapiro Statistic=0.608, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=55.835, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.594
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# high_plus1
# Shapiro Statistic=0.608, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=55.835, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.594
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# low_plus1
# Shapiro Statistic=0.608, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=55.835, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.594
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# close_plus1
# Shapiro Statistic=0.608, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=55.835, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.594
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# close_adj_plus1
# Shapiro Statistic=0.608, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=55.835, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.594
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# volume_plus1
# Shapiro Statistic=0.608, p=0.000 Sample does not look Gaussian (reject H0)
# D'Agostino Statistic=55.835, p=0.000 Sample does not look Gaussian (reject H0)
# Anderson Statistic=7.594
# 15.000: 0.530, data does not look normal (reject H0)
# 10.000: 0.604, data does not look normal (reject H0)
# 5.000: 0.725, data does not look normal (reject H0)
# 2.500: 0.845, data does not look normal (reject H0)
# 1.000: 1.005, data does not look normal (reject H0)
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# D:\Documents\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1785: RuntimeWarning: invalid value encountered in true_divide
#   w = (y - xbar) / s

# %% [markdown]
# I still see some processing issues here, and I finally see a very few "looks normal" responses, but still the majority are not normal even when looking at a single stock.
